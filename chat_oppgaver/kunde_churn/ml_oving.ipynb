# %%
# %pip install numpy
# %pip install matplotlib
# %pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("kunde_churn_tdt4172.csv")

# %%
print(df.dtypes)
should_not_use = ["kunde_id",]
must_normalize = ["tilfredshet", "alder", "maaneder_som_kunde", "maanedspris_kr", "ukentlig_bruk_timer", "support_henvendelser_6mnd"]

# Accuracy er en dårlig metric, da datene er skeivt fordelt

#########################################
## PREPROCESSING DATA ##
#########################################

data = df.dropna().copy()
y = data["chern"].copy()
X = data.drop(columns=["chern","kunde_id"]).copy()
X = convert_to_class(X, "kontrakt",)
X = convert_to_binary(X, "autotrekk")
X = normalize(X, must_normalize)

def convert_to_class(X: pd.DataFrame, column: str):
    mapping = {
        "Maaned": 0,
        "Ett_aar": 0.5,
        "To_aar": 1
    }

    X[column] = X[column].map(mapping)

    return X

def convert_to_binary(X: pd.DataFrame, column: str):
    mapping = {
        "Ja": 1,
        "Nei": 0
    }

    X[column] = X[column].map(mapping)

    return X

def normalize(X: pd.DataFrame, columns: list):
    for column in columns:
        minimum = X[column].min()
        maximum = X[column].max()

    X[column] = (
        (X[column] - minimum)
        / (maximum - minimum)
    )

    return X
# Out:
# kunde_id                           str
# alder                          float64
# maaneder_som_kunde               int64
# maanedspris_kr                 float64
# ukentlig_bruk_timer            float64
# supporthenvendelser_6mnd         int64
# forsinkede_betalinger_12mnd      int64
# kontrakt                           str
# autotrekk                          str
# tilfredshet                    float64
# churn                            int64
# dtype: object

# %%
class LogisticRegression:
    def __init__(self, learning_rate=0.1, epochs=1000):
        self.learning_rate = learning_rate
        self.epochs = epochs

        self.weights = None
        self.bias = None

        self.losses = []
        self.train_accuracies = []
    
    def sigmoid(self,z):
        return 1 / (1 + np.exp(-z))

    def compute_loss(self, y, y_pred):
        print("Computing loss")

    def compute_gradients(self, X, y, y_pred):
        print("Computing gradients")
    
    def update_parameters(self, grad_w, grad_b):
        print("Updating parameters")
    
    def fit(self,X: pd.DataFrame,y):
        print("Fitting model")
    
    def predict_proba(self,X):
        print("Predicting probabilities")
    
    def predict(self,X, threshold=0.5):
        print("Predicting")
